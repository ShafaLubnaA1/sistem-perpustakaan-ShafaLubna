# %% [markdown]
# <a href="https://colab.research.google.com/github/ShafaLubnaA1/sistem-perpustakaan-ShafaLubna/blob/main/sistem_perpustakaan_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program Perhitungan Denda Keterlambatan Pengembalian Buku
hari_terlambat = 5
denda_per_hari = 2000

total_denda = hari_terlambat * denda_per_hari
print(f"Total denda keterlambatan ({hari_terlambat} hari): Rp {total_denda}")
# Out:
# Total denda keterlambatan (5 hari): Rp 10000
